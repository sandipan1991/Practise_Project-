# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.histplot(x='R',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True,linewidth=2,linecolor='black',fmt='.2f')
plt.show()

# %%
sns.histplot(x='W',y='R',data=df)
plt.show()

# %%
sns.histplot(x='W',y='AB',data=df)
plt.show()

# %%
sns.histplot(x='W',y='H',data=df)
plt.show()

# %%
sns.histplot(x='W',y='2B',data=df)
plt.show()

# %%
sns.histplot(x='W',y='3B',data=df)
plt.show()

# %%
sns.histplot(x='W',y='HR',data=df)
plt.show()

# %%
sns.histplot(x='W',y='BB',data=df)
plt.show()

# %%
sns.histplot(x='W',y='SO',data=df)
plt.show()

# %%
sns.histplot(x='W',y='SB',data=df)
plt.show()

# %%
sns.histplot(x='W',y='RA',data=df)
plt.show()

# %%
sns.histplot(x='W',y='ER',data=df)
plt.show()

# %%
sns.histplot(x='W',y='ERA',data=df)
plt.show()

# %%
sns.histplot(x='W',y='CG',data=df)
plt.show()

# %%
sns.histplot(x='W',y='SHO',data=df)
plt.show()

# %%
sns.histplot(x='W',y='SV',data=df)
plt.show()

# %%
sns.histplot(x='W',y='E',data=df)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
x=df.iloc[:,:1]

# %%
x.head()
# Out:
#     W
# 0  95
# 1  83
# 2  81
# 3  76
# 4  74

# %%
y=df.iloc[:,1:2]

# %%
y.head()
# Out:
#      R
# 0  724
# 1  696
# 2  669
# 3  622
# 4  689

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=100)

# %%
cl = LogisticRegression()
cl.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
Pred_cl=cl.predict(x_test)

# %%
score=cl.score(x_test, y_test)

# %%
score
# Out:
# 0.1
